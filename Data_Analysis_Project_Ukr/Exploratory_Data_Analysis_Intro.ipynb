# %% [markdown]
# # Exploratory Data Analysis in Ukraine

# %% [markdown]
# ### Roles to Explore:

# %%
import ast
import pandas as pd
import seaborn as sns
import numpy as np
from datasets import load_dataset
import matplotlib.pyplot as plt
from matplotlib.ticker import FuncFormatter
from adjustText import adjust_text



# Loading Data
dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()



# Data Cleanup
df['job_posted_date'] = pd.to_datetime(df['job_posted_date']) 

# Transform job_skills from str to list by using apply method
df['job_skills'] = df['job_skills'].apply(lambda x: ast.literal_eval(x) if pd.notna(x) else x)

# %%
df_DA_UKR = df[(df['job_title_short'].isin(['Data Analyst', 'Data Scientist', 'Data Engineer'])) & (df['job_country'] == 'Ukraine')].copy()

df_DA_UKR['job_title_short'].value_counts()
# Out:
# job_title_short
# Data Analyst      473
# Data Engineer     374
# Data Scientist    232
# Name: count, dtype: int64

# %%
df_DA_UKR['job_location'] = df_DA_UKR['job_location'].replace('Ukraine', 'Anywhere')
df_DA_UKR['job_location'] = df_DA_UKR['job_location'].replace('Odesa, Odessa Oblast, Ukraine', 'Odesa, Odesa Oblast, Ukraine')
df_DA_UKR['job_location'] = df_DA_UKR['job_location'].replace('Ukraine  (+1 other)', 'Anywhere')
df_DA_UKR['job_location'] = df_DA_UKR['job_location'].replace('Ukraine (+1 other)', 'Anywhere')
df_DA_UKR['job_location'] = df_DA_UKR['job_location'].replace('Ukraine (+2 others)', 'Anywhere')
df_DA_UKR['job_location'] = df_DA_UKR['job_location'].replace('Ukrainka, Kyiv Oblast, Ukraine', 'Kyiv, Ukraine')


# Company name 
df_DA_UKR['company_name'] = df_DA_UKR['company_name'].replace('Перший Український Міжнародний Банк, АТ / ПУМБ', 'ПУМБ')


df_DA_UKR['job_location'].value_counts().to_frame()
# Out:
#                                                   count
# job_location
# Kyiv, Ukraine                                       503
# Anywhere                                            433
# Lviv, Lviv Oblast, Ukraine                           51
# Odesa, Odesa Oblast, Ukraine                         42
# Dnipro, Dnipropetrovsk Oblast, Ukraine               20
# Kharkiv, Kharkiv Oblast, Ukraine                     10
# Vinnytsia, Vinnytsia Oblast, Ukraine                  7
# Poltava, Poltava Oblast, Ukraine                      4
# Chernivtsi, Chernivtsi Oblast, Ukraine                3
# Khmelnytskyi, Khmelnytskyi Oblast, Ukraine            2
# Ternopil, Ternopil Oblast, Ukraine                    1
# Ivano-Frankivsk, Ivano-Frankivsk Oblast, Ukraine      1
# Kropyvnytskyi, Kirovohrad Oblast, Ukraine             1
# Cherkasy, Cherkasy Oblast, Ukraine                    1

# %%
# Function to extract city name
def extract_city(location):
    if location == 'Anywhere':
        return location
    else:
        return location.split(',')[0]

# Apply the function to the `job_location` column and create a new column
df_DA_UKR['city'] = df_DA_UKR['job_location'].apply(extract_city)

df_DA_UKR.sample(10)
# Out:
#        job_title_short                                          job_title  \
# 391918    Data Analyst         Technical Support Engineer | Analytics Pod
# 230772   Data Engineer                                      Data Engineer
# 140185  Data Scientist                                     Data Scientist
# 484085   Data Engineer  Middle Data Engineer (Communication Management...
# 695455    Data Analyst  Data Analyst: Training and Project Work (remot...
# 177773  Data Scientist                                     Data Scientist
# 181513    Data Analyst                                       Data Analyst
# 218400    Data Analyst                                       Data Analyst
# 6460     Data Engineer  Integration/Data Engineer for Azure Platform I...
# 438368   Data Engineer                                      Data Engineer
#
#                       job_location                   job_via  \
# 391918               Kyiv, Ukraine  via Вакансии Trabajo.org
# 230772               Kyiv, Ukraine  via Вакансии Trabajo.org
# 140185  Lviv, Lviv Oblast, Ukraine           via Ai-Jobs.net
# 484085               Kyiv, Ukraine             via Rabota.ua
# 695455                    Anywhere              via LinkedIn
# 177773                    Anywhere              via LinkedIn
# 181513               Kyiv, Ukraine             via Rabota.ua
# 218400               Kyiv, Ukraine             via RABOTA.ua
# 6460                 Kyiv, Ukraine              via LinkedIn
# 438368               Kyiv, Ukraine              via LinkedIn
#
#        job_schedule_type  job_work_from_home search_location  \
# 391918         Full-time               False         Ukraine
# 230772         Full-time               False         Ukraine
# 140185         Full-time               False         Ukraine
# 484085         Full-time               False         Ukraine
# 695455         Part-time                True         Ukraine
# 177773         Full-time                True         Ukraine
# 181513         Full-time               False         Ukraine
# 218400         Full-time               False         Ukraine
# 6460           Full-time               False         Ukraine
# 438368         Full-time               False         Ukraine
#
#            job_posted_date  job_no_degree_mention  job_health_insurance  \
# 391918 2023-05-26 18:27:08                   True                 False
# 230772 2023-01-18 07:37:45                   True                 False
# 140185 2023-06-28 09:04:05                  False                 False
# 484085 2023-05-19 14:06:24                   True                 False
# 695455 2023-10-01 10:26:47                   True                 False
# 177773 2023-03-02 15:32:28                  False                 False
# 181513 2023-05-17 15:52:36                   True                 False
# 218400 2023-02-01 23:49:27                   True                 False
# 6460   2023-04-11 14:14:43                   True                 False
# 438368 2023-09-05 16:24:14                   True                 False
#
#        job_country salary_rate  salary_year_avg  salary_hour_avg  \
# 391918     Ukraine        None              NaN              NaN
# 230772     Ukraine        None              NaN              NaN
# 140185     Ukraine        year         132500.0              NaN
# 484085     Ukraine        None              NaN              NaN
# 695455     Ukraine        None              NaN              NaN
# 177773     Ukraine        None              NaN              NaN
# 181513     Ukraine        None              NaN              NaN
# 218400     Ukraine        None              NaN              NaN
# 6460       Ukraine        None              NaN              NaN
# 438368     Ukraine        None              NaN              NaN
#
#                company_name  \
# 391918              Sisense
# 230772              Genesis
# 140185             Gameloft
# 484085       Sigma Software
# 695455                Moyyn
# 177773           JustAnswer
# 181513              Софтіко
# 218400  Kyivstar / Киевстар
# 6460            GlobalLogic
# 438368                Uklon
#
#                                                job_skills  \
# 391918  [sql, javascript, nosql, mongodb, mongodb, she...
# 230772  [python, sql, bigquery, airflow, hadoop, spark...
# 140185  [python, sql, matplotlib, seaborn, tableau, po...
# 484085                                               None
# 695455                                           [python]
# 177773                                      [python, sql]
# 181513                                               None
# 218400                                               None
# 6460                              [c#, sql, nosql, azure]
# 438368  [sql, python, java, scala, postgresql, snowfla...
#
#                                           job_type_skills      city
# 391918  {'analyst_tools': ['power bi', 'ssrs', 'cognos...      Kyiv
# 230772  {'cloud': ['bigquery'], 'libraries': ['airflow...      Kyiv
# 140185  {'analyst_tools': ['tableau', 'power bi'], 'li...      Lviv
# 484085                                               None      Kyiv
# 695455                        {'programming': ['python']}  Anywhere
# 177773                 {'programming': ['python', 'sql']}  Anywhere
# 181513                                               None      Kyiv
# 218400                                               None      Kyiv
# 6460    {'cloud': ['azure'], 'programming': ['c#', 'sq...      Kyiv
# 438368  {'cloud': ['snowflake', 'aws', 'bigquery', 're...      Kyiv

# %%
# Removed the 'job_location' column & renamed the 'city' column to 'job_location'
df_DA_UKR.drop('job_location', axis=1, inplace=True)
df_DA_UKR.rename(columns={'city': 'job_location'}, inplace=True)

df_DA_UKR
# Out:
#        job_title_short                                          job_title  \
# 275      Data Engineer                        Інженер з договірної роботи
# 524       Data Analyst                                       Data analyst
# 655      Data Engineer  Middle Data Engineer (Communication Management...
# 855     Data Scientist                  Data Scientist (Machine Learning)
# 1484    Data Scientist                     Middle Data Scientist/Engineer
# ...                ...                                                ...
# 774775   Data Engineer          Azure Data Lifecycle Engineer (Developer)
# 775837  Data Scientist                              Data Scientist | Zeki
# 775915    Data Analyst                                       Data Analyst
# 781080    Data Analyst                Team Lead Supply Chain Data Analyst
# 782549    Data Analyst                                Middle Data Analyst
#
#                          job_via job_schedule_type  job_work_from_home  \
# 275                via RABOTA.ua         Full-time               False
# 524                via Robota.ua         Full-time               False
# 655                via Rabota.ua         Full-time               False
# 855                via Robota.ua         Full-time               False
# 1484                  via Jooble         Full-time               False
# ...                          ...               ...                 ...
# 774775          via Startup Jobs         Full-time               False
# 775837                via Jooble         Full-time                True
# 775915          via Startup Jobs         Full-time               False
# 781080              via LinkedIn         Full-time               False
# 782549  via Вакансии Trabajo.org         Full-time               False
#
#        search_location     job_posted_date  job_no_degree_mention  \
# 275            Ukraine 2023-01-24 13:51:43                   True
# 524            Ukraine 2023-07-11 13:47:33                   True
# 655            Ukraine 2023-06-02 13:43:32                   True
# 855            Ukraine 2023-09-15 13:47:48                  False
# 1484           Ukraine 2023-12-19 13:50:16                  False
# ...                ...                 ...                    ...
# 774775         Ukraine 2023-03-04 01:26:34                   True
# 775837         Ukraine 2023-02-06 02:04:05                  False
# 775915         Ukraine 2023-03-04 01:26:30                   True
# 781080         Ukraine 2023-09-25 06:17:44                  False
# 782549         Ukraine 2023-05-28 06:21:24                   True
#
#         job_health_insurance job_country salary_rate  salary_year_avg  \
# 275                    False     Ukraine        None              NaN
# 524                    False     Ukraine        None              NaN
# 655                    False     Ukraine        None              NaN
# 855                    False     Ukraine        None              NaN
# 1484                   False     Ukraine        None              NaN
# ...                      ...         ...         ...              ...
# 774775                 False     Ukraine        None              NaN
# 775837                 False     Ukraine        None              NaN
# 775915                 False     Ukraine        None              NaN
# 781080                 False     Ukraine        None              NaN
# 782549                 False     Ukraine        None              NaN
#
#         salary_hour_avg            company_name  \
# 275                 NaN        Vodafone Україна
# 524                 NaN  Fozzy Group, Логістика
# 655                 NaN          Sigma Software
# 855                 NaN               ФОРА, ООО
# 1484                NaN         Data Science UA
# ...                 ...                     ...
# 774775              NaN                Kyivstar
# 775837              NaN                      GT
# 775915              NaN                Kyivstar
# 781080              NaN                 AUTODOC
# 782549              NaN                 Genesis
#
#                                                job_skills  \
# 275                                                  None
# 524                                                  None
# 655                                                  None
# 855                                                  None
# 1484     [sql, nosql, numpy, pandas, scikit-learn, flask]
# ...                                                   ...
# 774775  [sql, r, nosql, java, scala, python, azure, da...
# 775837                     [python, sql, go, aws, pandas]
# 775915  [html, javascript, sql, firebase, firebase, bi...
# 781080                               [sql, python, excel]
# 782549                                          [tableau]
#
#                                           job_type_skills job_location
# 275                                                  None       Dnipro
# 524                                                  None         Kyiv
# 655                                                  None   Chernivtsi
# 855                                                  None         Kyiv
# 1484    {'libraries': ['numpy', 'pandas', 'scikit-lear...         Kyiv
# ...                                                   ...          ...
# 774775  {'cloud': ['azure', 'databricks'], 'libraries'...         Kyiv
# 775837  {'cloud': ['aws'], 'libraries': ['pandas'], 'p...     Anywhere
# 775915  {'analyst_tools': ['power bi'], 'cloud': ['fir...         Kyiv
# 781080  {'analyst_tools': ['excel'], 'programming': ['...        Odesa
# 782549                     {'analyst_tools': ['tableau']}         Kyiv
#
# [1079 rows x 17 columns]

# %%
df_DA_plot = df_DA_UKR['job_location'].value_counts().to_frame()

sns.set_theme(style='ticks')
sns.barplot(data=df_DA_plot, x='count', y='job_location', hue='count', palette='dark:#5A9_r', legend= False)
sns.despine()
plt.suptitle('Counts of Job Locations in Ukraine', fontsize=14)
plt.title('For Data Analysts, Data Engineers, Data Scientists', fontsize=10)
plt.xlabel('Number of Jobs', fontsize=10)
plt.ylabel('')
plt.xticks(range(0, 600, 50))
plt.show()

# %%
# Create a list of values to filter out
values_to_remove = ['Internship', 'Full-time and Internship', 'Full-time and Part-time', 'Temp work']

# Filter the DataFrame using the `isin()` method
rows_to_drop = df_DA_UKR[df_DA_UKR['job_schedule_type'].isin(values_to_remove)].index

# Drop the rows
df_DA_UKR.drop(rows_to_drop, inplace=True)

df_DA_UKR['job_schedule_type'].value_counts()
# Out:
# job_schedule_type
# Full-time     1029
# Contractor      24
# Part-time       15
# Name: count, dtype: int64

# %%
dict_column = {
    'job_work_from_home': 'Work from Home',
    'job_no_degree_mention': 'Job Degree Req.',
    'job_schedule_type': 'Job Schedule Type'
}

fig, ax = plt.subplots(1, 3)
fig.set_size_inches((12, 5))

for i, (column, title) in enumerate(dict_column.items()):
    if i == 2:  # Check if it's the last pie chart
        data = df_DA_UKR[column].value_counts().values
        labels = df_DA_UKR[column].value_counts().index.to_numpy()
    else:
        # Data and labels for the first two pie charts remain the same
        data = df_DA_UKR[column].value_counts()
        labels = ['False', 'True']

    ax[i].pie(data, startangle=90, autopct='%1.1f%%', labels=labels)
    ax[i].set_title(title)

plt.show()

# %%
df_DA_companies = df_DA_UKR['company_name'].value_counts().head(30).to_frame()

df_DA_companies
# Out:
#                        count
# company_name
# AUTODOC                   47
# Genesis                   29
# EPAM Systems              23
# GlobalLogic               22
# N-iX                      21
# Lyft                      16
# Sigma Software            15
# Intellias                 14
# Ciklum                    13
# ПУМБ                      12
# ROZETKA                   10
# SoftServe                 10
# Hitachi Careers           10
# SKELAR                    10
# Wix                        9
# EvoPlay                    9
# Uklon                      8
# Deep Knowledge Group       8
# Mercy Corps                7
# GlobalLogic Ukraine        6
# METRO/MAKRO                6
# Data Science UA            6
# Kyivstar / Киевстар        6
# Simulmedia                 6
# JatApp                     6
# Gameloft                   6
# Capgemini Engineering      6
# ПриватБанк                 6
# Kyivstar                   5
# Райффайзен Банк            5

# %%
df_DA_companies = df_DA_UKR['company_name'].value_counts().to_frame().head(30)

plt.figure(figsize=(10, 8))
sns.set_theme(style='ticks')
sns.barplot(data=df_DA_companies, x='count', y='company_name', hue='count', palette='dark:#5A9_r', legend= False)
sns.despine()
plt.suptitle('Top 30 Tech Companies Hiring in Ukraine', fontsize=14)
plt.title('For Data Analysts, Data Engineers, Data Scientists', fontsize=10)
plt.xlabel('Number of Jobs', fontsize=10)
plt.ylabel('')
plt.xticks(range(0, 60, 5))
plt.tight_layout()
plt.show()

# %%
dict_column = {
    'job_work_from_home': 'Work from Home',
    'job_no_degree_mention': 'Degree Required',
    'job_schedule_type': 'Job Schedule Type'
}

fig, ax = plt.subplots(1, 3)
fig.set_size_inches((12, 5))

for i, (column, title) in enumerate(dict_column.items()):
    if i == 2:  # Check if it's the last pie chart
        data = df_DA_UKR[column].value_counts().values
        labels = df_DA_UKR[column].value_counts().index.to_numpy()
        #explode = [0, 0.1, 0.1]  # Explode the "Part-time" and "Contractor" slices
    else:
        # Data and labels for the first two pie charts remain the same
        data = df_DA_UKR[column].value_counts()
        labels = ['False', 'True']
        explode = None

    ax[i].pie(data, startangle=90, autopct='%1.1f%%', labels=labels, explode=explode,
             textprops={'fontsize': 12})  # Adjust font size if needed
    ax[i].set_title(title)

    # Adjust text for the third pie chart
    if i == 2:
        texts = ax[i].texts
        # Adjust the position of the "1.4%" label
        texts[1].set_position((0.5, -0.1))  # Adjust x and y coordinates as needed
        # Remove arrowprops and force text adjustment
        adjust_text(texts, force_points=0.2, force_text=0.6, arrowprops=None)

plt.show()
